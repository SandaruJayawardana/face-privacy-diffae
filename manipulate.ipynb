# %%
# %load_ext autoreload
# %autoreload 2

# %%
from templates import *
from templates_cls import *
from experiment_classifier import ClsModel

# %%
device = 'cuda:3'
conf = ffhq256_autoenc()
# print(conf.name)
model = LitModel(conf)
state = torch.load(f'checkpoints/{conf.name}/last.ckpt', map_location='cpu')
model.load_state_dict(state['state_dict'], strict=False)
model.ema_model.eval()
model.ema_model.to(device);
# Out:
# Global seed set to 0
# Model params: 160.69 M

# %%
cls_conf = ffhq256_autoenc_cls()
cls_model = ClsModel(cls_conf)/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/checkpoints
state = torch.load(f'/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/checkpoints/{cls_conf.name}/last.ckpt',
                    map_location='cpu')
print('latent step:', state['global_step'])
cls_model.load_state_dict(state['state_dict'], strict=False);
cls_model.to(device);
# Out:
# Global seed set to 0
# loading pretrain ... 130M
# step: 1563562
# loading latent stats ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb Cell 4 line 3
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> cls_conf = ffhq256_autoenc_cls()
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> cls_model = ClsModel(cls_conf)
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> state = torch.load(f'/home/sjay9734/diff_encoder/diffae/checkpoints/{cls_conf.name}/last.ckpt',
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>                     map_location='cpu')
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> print('latent step:', state['global_step'])
#       <a href='vscode-notebook-cell://ssh-remote%2Bgpu4-0.cs.usyd.edu.au/home/sjay9734/diff_encoder/face_privacy/face-privacy-diffae/manipulate.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> cls_model.load_state_dict(state['state_dict'], strict=False);
#
# File ~/diff_encoder/lib/python3.10/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File ~/diff_encoder/lib/python3.10/site-packages/torch/serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File ~/diff_encoder/lib/python3.10/site-packages/torch/serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/sjay9734/diff_encoder/diffae/checkpoints/ffhq256_autoenc_cls/last.ckpt'

# %%
# data = conf.make_dataset()
# batch = data[10]['img'][None]

# %%
data = ImageDataset('imgs_align', image_size=conf.img_size, exts=['jpg', 'JPG', 'png'], do_augment=False)
batch = data[0]['img'][None]

# %%
cond = model.encode(batch.to(device))
xT = model.encode_stochastic(batch.to(device), cond, T=250)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ori = (batch + 1) / 2
ax[0].imshow(ori[0].permute(1, 2, 0).cpu())
ax[1].imshow(xT[0].permute(1, 2, 0).cpu())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
print(CelebAttrDataset.id_to_cls)
# Out:
# ['5_o_Clock_Shadow', 'Arched_Eyebrows', 'Attractive', 'Bags_Under_Eyes', 'Bald', 'Bangs', 'Big_Lips', 'Big_Nose', 'Black_Hair', 'Blond_Hair', 'Blurry', 'Brown_Hair', 'Bushy_Eyebrows', 'Chubby', 'Double_Chin', 'Eyeglasses', 'Goatee', 'Gray_Hair', 'Heavy_Makeup', 'High_Cheekbones', 'Male', 'Mouth_Slightly_Open', 'Mustache', 'Narrow_Eyes', 'No_Beard', 'Oval_Face', 'Pale_Skin', 'Pointy_Nose', 'Receding_Hairline', 'Rosy_Cheeks', 'Sideburns', 'Smiling', 'Straight_Hair', 'Wavy_Hair', 'Wearing_Earrings', 'Wearing_Hat', 'Wearing_Lipstick', 'Wearing_Necklace', 'Wearing_Necktie', 'Young']

# %%
cls_id = CelebAttrDataset.cls_to_id['Wavy_Hair']

# %%
cond2 = cls_model.normalize(cond)
cond2 = cond2 + 0.3 * math.sqrt(512) * F.normalize(cls_model.classifier.weight[cls_id][None, :], dim=1)
cond2 = cls_model.denormalize(cond2)

# %%
import matplotlib.pyplot as plt
# torch.manual_seed(1)
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
img = model.render(xT, cond2, T=100)
ori = (batch + 1) / 2
ax[0].imshow(ori[0].permute(1, 2, 0).cpu())
ax[1].imshow(img[0].permute(1, 2, 0).cpu())
plt.savefig('imgs_manipulated/compare.png')

# %%
from torchvision.utils import *
save_image(img[0], 'imgs_manipulated/output.png')
